# %% [markdown]
# # CIFAR-10 dataset classification with MLPs
#
# Author: Tanwi Mallick, adapting codes from Bethany Lusch, Prasanna Balprakash, Corey Adams, and Kyle Felker
#
# In this notebook, we'll continue the CIFAR-10 problem but using the Keras API (as included in the TensorFlow library)
#
# First, the needed imports.

# %%
# %matplotlib inline


import tensorflow as tf

import numpy
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## CIFAR-10 data set
#
# Again we'll load the cifar10 data set. CIFAR-10 dataset contains 32x32 color images from 10 classes: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck. If you haven't downloaded it already, it could take a while.
#
# <img src="images/CIFAR-10.png"  align="left"/>

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train.astype(numpy.float32)
x_test  = x_test.astype(numpy.float32)

x_train /= 255.
x_test  /= 255.

y_train = y_train.astype(numpy.int32)
y_test  = y_test.astype(numpy.int32)

print()
print('CIFAR-10 data loaded: train:',len(x_train),'test:',len(x_test))
print('X_train:', x_train.shape)
print('y_train:', y_train.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/urllib/request.py:1354, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1353 try:
# -> 1354     h.request(req.get_method(), req.selector, req.data, headers,
#    1355               encode_chunked=req.has_header('Transfer-encoding'))
#    1356 except OSError as err: # timeout error
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/http/client.py:1256, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1255 """Send a complete request to the server."""
# -> 1256 self._send_request(method, url, body, headers, encode_chunked)
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/http/client.py:1302, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1301     body = _encode(body, 'body')
# -> 1302 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/http/client.py:1251, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1250     raise CannotSendHeader()
# -> 1251 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/http/client.py:1011, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1010 del self._buffer[:]
# -> 1011 self.send(msg)
#    1013 if message_body is not None:
#    1014
#    1015     # create a consistent interface to message_body
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/http/client.py:951, in HTTPConnection.send(self, data)
#     950 if self.auto_open:
# --> 951     self.connect()
#     952 else:
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/http/client.py:1418, in HTTPSConnection.connect(self)
#    1416 "Connect to a host on a given (SSL) port."
# -> 1418 super().connect()
#    1420 if self._tunnel_host:
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/http/client.py:922, in HTTPConnection.connect(self)
#     921 """Connect to the host and port specified in __init__."""
# --> 922 self.sock = self._create_connection(
#     923     (self.host,self.port), self.timeout, self.source_address)
#     924 self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/socket.py:808, in create_connection(address, timeout, source_address)
#     807 try:
# --> 808     raise err
#     809 finally:
#     810     # Break explicitly a reference cycle
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/socket.py:796, in create_connection(address, timeout, source_address)
#     795     sock.bind(source_address)
# --> 796 sock.connect(sa)
#     797 # Break explicitly a reference cycle
#
# OSError: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/keras/utils/data_utils.py:283, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     282 try:
# --> 283   urlretrieve(origin, fpath, DLProgbar())
#     284 except urllib.error.HTTPError as e:
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/keras/utils/data_utils.py:82, in urlretrieve(url, filename, reporthook, data)
#      80       break
# ---> 82 response = urlopen(url, data)
#      83 with open(filename, 'wb') as fd:
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/urllib/request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     524 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525 response = self._open(req, data)
#     527 # post-process response
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/urllib/request.py:542, in OpenerDirector._open(self, req, data)
#     541 protocol = req.type
# --> 542 result = self._call_chain(self.handle_open, protocol, protocol +
#     543                           '_open', req)
#     544 if result:
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     501 func = getattr(handler, meth_name)
# --> 502 result = func(*args)
#     503 if result is not None:
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/urllib/request.py:1397, in HTTPSHandler.https_open(self, req)
#    1396 def https_open(self, req):
# -> 1397     return self.do_open(http.client.HTTPSConnection, req,
#    1398         context=self._context, check_hostname=self._check_hostname)
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/urllib/request.py:1357, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1356 except OSError as err: # timeout error
# -> 1357     raise URLError(err)
#    1358 r = h.getresponse()
#
# URLError: <urlopen error [Errno 101] Network is unreachable>
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
#       2 x_train = x_train.astype(numpy.float32)
#       3 x_test  = x_test.astype(numpy.float32)
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/keras/datasets/cifar10.py:79, in load_data()
#      77 dirname = 'cifar-10-batches-py'
#      78 origin = 'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz'
# ---> 79 path = get_file(
#      80     dirname,
#      81     origin=origin,
#      82     untar=True,
#      83     file_hash=
#      84     '6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce')
#      86 num_train_samples = 50000
#      88 x_train = np.empty((num_train_samples, 3, 32, 32), dtype='uint8')
#
# File /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/keras/utils/data_utils.py:287, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     285     raise Exception(error_msg.format(origin, e.code, e.msg))
#     286   except urllib.error.URLError as e:
# --> 287     raise Exception(error_msg.format(origin, e.errno, e.reason))
#     288 except (Exception, KeyboardInterrupt) as e:
#     289   if os.path.exists(fpath):
#
# Exception: URL fetch failure on https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz: None -- [Errno 101] Network is unreachable

# %% [markdown]
# ### Download the dataset and load

# %%
# !https_proxy=http://proxy.tmi.alcf.anl.gov:3128  pip install image-dataset-loader
# !https_proxy=http://proxy.tmi.alcf.anl.gov:3128  wget https://s3.amazonaws.com/fast-ai-imageclas/cifar10.tgz
# !tar -xf cifar10.tgz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: image-dataset-loader in /home/arsho/.local/lib/python3.8/site-packages (0.0.0)
# Requirement already satisfied: numpy>=1.0.0 in /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages (from image-dataset-loader) (1.23.0)
# Requirement already satisfied: imageio>=2.0.0 in /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages (from image-dataset-loader) (2.19.3)
# Requirement already satisfied: pillow>=8.3.2 in /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages (from imageio>=2.0.0->image-dataset-loader) (9.2.0)
# --2022-10-04 16:26:49--  https://s3.amazonaws.com/fast-ai-imageclas/cifar10.tgz
# Resolving proxy.tmi.alcf.anl.gov (proxy.tmi.alcf.anl.gov)... 10.236.1.189
# Connecting to proxy.tmi.alcf.anl.gov (proxy.tmi.alcf.anl.gov)|10.236.1.189|:3128... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 135107811 (129M) [application/x-tar]
# Saving to: ‘cifar10.tgz.4’
#
# cifar10.tgz.4       100%[===================>] 128.85M  84.2MB/s    in 1.5s
#
# 2022-10-04 16:26:50 (84.2 MB/s) - ‘cifar10.tgz.4’ saved [135107811/135107811]

# %%
from image_dataset_loader import load
(x_train, y_train), (x_test, y_test) = load('cifar10', ['train', 'test'])

x_train = x_train.astype(numpy.float32)
x_test  = x_test.astype(numpy.float32)

x_train /= 255.
x_test  /= 255.

y_train = y_train.astype(numpy.int32)
y_test  = y_test.astype(numpy.int32)

print()
print('CIFAR-10 data loaded: train:',len(x_train),'test:',len(x_test))
print('X_train:', x_train.shape)
print('y_train:', y_train.shape)
# Out:
# CIFAR-10 data loaded: train: 50000 test: 10000
# X_train: (50000, 32, 32, 3)
# y_train: (50000,)

# %% [markdown]
# This time we won't flatten the images upfront.
#
# The training data (`X_train`) is a 3rd-order tensor of size (50000, 32, 32), i.e. it consists of 50000 images of size 32x32 pixels.
#
# `y_train` is a 50000-dimensional vector containing the correct classes ('airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck') for each training sample.

# %% [markdown]
# <img src="images/image_representation.png"  align="left"/>

# %% [markdown]
# ## Linear model
#
# ### Initialization
#
# Let's begin with a simple linear model, but with the Keras library. First we use a `Flatten` layer to convert image data into vectors.
#
# A `Dense()` layer is a basic layer: $xW + b$ with an optional nonlinearity applied ("activation function"). The `Dense` layer connects each input to each output with some weight parameter. They are also called "fully connected."
#
# Here we add a `Dense` layer that has $32\times32\times3=3072$ input nodes (one for each pixel in the input image) and 10 output nodes.

# %%
class LinearClassifier(tf.keras.models.Model):

    def __init__(self, activation=tf.nn.tanh):
        tf.keras.models.Model.__init__(self)

        self.layer_1 = tf.keras.layers.Dense(10, activation='softmax')


    def call(self, inputs):

        x = tf.keras.layers.Flatten()(inputs)
        x = self.layer_1(x)

        return x

# %% [markdown]
# We select *sparse categorical crossentropy* as the loss function, select [*stochastic gradient descent*](https://keras.io/optimizers/#sgd) as the optimizer, add *accuracy* to the list of metrics to be evaluated, and `compile()` the model. Note there are [several different options](https://keras.io/optimizers/) for the optimizer in Keras that we could use instead of *sgd*.

# %%
linear_model = LinearClassifier()

linear_model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=['accuracy'])

# %% [markdown]
# ### Learning

# %% [markdown]
# Now we are ready to train our first model. An epoch means one pass through the whole training data.

# %% [markdown]
# Here is a concise way to train the network. The fit function handles looping over the batches. We'll see a more verbose approach in the next notebook that allows more performance tuning.

# %% [markdown]
# You can run the code below multiple times and it will continue the training process from where it left off. If you want to start from scratch, re-initialize the model using the code a few cells ago.

# %%
# %%time
# This took about a third of a second per epoch on my laptop
batch_size = 512
epochs = 30
history = linear_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=2)
# Out:
# Epoch 1/30
# 98/98 - 1s - loss: 2.1507 - accuracy: 0.2189 - 1s/epoch - 11ms/step
# Epoch 2/30
# 98/98 - 0s - loss: 1.9944 - accuracy: 0.2952 - 185ms/epoch - 2ms/step
# Epoch 3/30
# 98/98 - 0s - loss: 1.9364 - accuracy: 0.3231 - 175ms/epoch - 2ms/step
# Epoch 4/30
# 98/98 - 0s - loss: 1.9028 - accuracy: 0.3377 - 175ms/epoch - 2ms/step
# Epoch 5/30
# 98/98 - 0s - loss: 1.8808 - accuracy: 0.3461 - 175ms/epoch - 2ms/step
# Epoch 6/30
# 98/98 - 0s - loss: 1.8636 - accuracy: 0.3547 - 173ms/epoch - 2ms/step
# Epoch 7/30
# 98/98 - 0s - loss: 1.8502 - accuracy: 0.3589 - 170ms/epoch - 2ms/step
# Epoch 8/30
# 98/98 - 0s - loss: 1.8398 - accuracy: 0.3645 - 165ms/epoch - 2ms/step
# Epoch 9/30
# 98/98 - 0s - loss: 1.8305 - accuracy: 0.3673 - 173ms/epoch - 2ms/step
# Epoch 10/30
# 98/98 - 0s - loss: 1.8234 - accuracy: 0.3700 - 169ms/epoch - 2ms/step
# Epoch 11/30
# 98/98 - 0s - loss: 1.8172 - accuracy: 0.3719 - 171ms/epoch - 2ms/step
# Epoch 12/30
# 98/98 - 0s - loss: 1.8101 - accuracy: 0.3748 - 169ms/epoch - 2ms/step
# Epoch 13/30
# 98/98 - 0s - loss: 1.8057 - accuracy: 0.3776 - 170ms/epoch - 2ms/step
# Epoch 14/30
# 98/98 - 0s - loss: 1.8002 - accuracy: 0.3794 - 167ms/epoch - 2ms/step
# Epoch 15/30
# 98/98 - 0s - loss: 1.7962 - accuracy: 0.3800 - 168ms/epoch - 2ms/step
# Epoch 16/30
# 98/98 - 0s - loss: 1.7929 - accuracy: 0.3812 - 170ms/epoch - 2ms/step
# Epoch 17/30
# 98/98 - 0s - loss: 1.7882 - accuracy: 0.3827 - 174ms/epoch - 2ms/step
# Epoch 18/30
# 98/98 - 0s - loss: 1.7840 - accuracy: 0.3843 - 171ms/epoch - 2ms/step
# Epoch 19/30
# 98/98 - 0s - loss: 1.7821 - accuracy: 0.3866 - 168ms/epoch - 2ms/step
# Epoch 20/30
# 98/98 - 0s - loss: 1.7781 - accuracy: 0.3885 - 168ms/epoch - 2ms/step
# Epoch 21/30
# 98/98 - 0s - loss: 1.7754 - accuracy: 0.3888 - 169ms/epoch - 2ms/step
# Epoch 22/30
# 98/98 - 0s - loss: 1.7723 - accuracy: 0.3905 - 166ms/epoch - 2ms/step
# Epoch 23/30
# 98/98 - 0s - loss: 1.7701 - accuracy: 0.3917 - 166ms/epoch - 2ms/step
# Epoch 24/30
# 98/98 - 0s - loss: 1.7682 - accuracy: 0.3915 - 167ms/epoch - 2ms/step
# Epoch 25/30
# 98/98 - 0s - loss: 1.7658 - accuracy: 0.3935 - 169ms/epoch - 2ms/step
# Epoch 26/30
# 98/98 - 0s - loss: 1.7630 - accuracy: 0.3943 - 169ms/epoch - 2ms/step
# Epoch 27/30
# 98/98 - 0s - loss: 1.7615 - accuracy: 0.3961 - 165ms/epoch - 2ms/step
# Epoch 28/30
# 98/98 - 0s - loss: 1.7595 - accuracy: 0.3952 - 165ms/epoch - 2ms/step
# Epoch 29/30
# 98/98 - 0s - loss: 1.7574 - accuracy: 0.3963 - 165ms/epoch - 2ms/step
# Epoch 30/30
# 98/98 - 0s - loss: 1.7560 - accuracy: 0.3964 - 161ms/epoch - 2ms/step
# CPU times: user 9.97 s, sys: 1.63 s, total: 11.6 s
# Wall time: 6.57 s

# %%
print(linear_model.summary())
# Out:
# Model: "linear_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               multiple                  30730
#
# =================================================================
# Total params: 30,730
# Trainable params: 30,730
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# The summary shows that there are 30730 parameters in our model, as the weight matrix is of size 3072x10, plus there's a bias vector of 10x1.

# %% [markdown]
# Let's now see how the training progressed.
#
# * *Loss* is a function of the difference of the network output and the target values.  We are minimizing the loss function during training so it should decrease over time.
# * *Accuracy* is the classification accuracy for the training data (100*accuracy is the percentage labeled correctly), so it should increase over time
#
# Note that for either measure, we cannot fully trust the progress, as the model may have overfitted and just memorized the training data.

# %%
plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['loss'])
plt.title('loss')

plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['accuracy'])
plt.title('accuracy');

# %% [markdown]
# ### Inference
#
# For a better measure of the quality of the model, let's see the model accuracy for the test data.

# %%
linscores = linear_model.evaluate(x_test, y_test, verbose=2)
print("%s: %.2f%%" % (linear_model.metrics_names[1], linscores[1]*100))
# Out:
# 313/313 - 0s - loss: 1.7668 - accuracy: 0.3893 - 366ms/epoch - 1ms/step
# accuracy: 38.93%

# %% [markdown]
# We can now take a closer look on the results.
#
# Let's define a helper function to show the failure cases of our classifier.

# %%
def show_failures(predictions, trueclass=None, predictedclass=None, maxtoshow=20):
    rounded = numpy.argmax(predictions, axis=1)
    errors = rounded!=y_test.flatten()
    print('Showing max', maxtoshow, 'first failures. '
          'The predicted class is shown first and the correct class in parenthesis.')
    ii = 0
    plt.figure(figsize=(maxtoshow, 1))
    for i in range(x_test.shape[0]):
        if ii>=maxtoshow:
            break
        if errors[i]:
            if trueclass is not None and y_test[i] != trueclass:
                continue
            if predictedclass is not None and rounded[i] != predictedclass:
                continue
            plt.subplot(1, maxtoshow, ii+1)
            plt.axis('off')
            plt.imshow(x_test[i,:,:], cmap="gray")
            plt.title("%d (%d)" % (rounded[i], y_test[i]))
            ii = ii + 1

# %% [markdown]
# Here are the first 10 test images the linear model classified to a wrong class:

# %%
linpredictions = linear_model.predict(x_test)

show_failures(linpredictions)
# Out:
# 313/313 [==============================] - 0s 625us/step
# Showing max 20 first failures. The predicted class is shown first and the correct class in parenthesis.

# %% [markdown]
# ## Multi-layer perceptron (MLP) network
#
# ### Initialization
#
# Let's now create a more complex MLP model that has multiple layers, non-linear activation functions, and dropout layers.
#
# `Dropout()` randomly sets a fraction of inputs to zero during training, which is one approach to regularization and can sometimes help to prevent overfitting.
#
# There are two options below, a simple and a bit more complex model.  Select either one.
#
# The output of the last layer needs to be a softmaxed 10-dimensional vector to match the groundtruth (`y_train`).

# %%
class NonlinearClassifier(tf.keras.models.Model):

    def __init__(self, activation=tf.nn.tanh):
        tf.keras.models.Model.__init__(self)

        self.layer_1 = tf.keras.layers.Dense(50, activation='relu')
        
#         # A bit more complex model: (need to uncomment in call fn as well)
        self.layer_2 = tf.keras.layers.Dense(50, activation='relu')
        self.drop_3 = tf.keras.layers.Dropout(0.2)
        self.layer_4 = tf.keras.layers.Dense(50, activation='relu')
        self.drop_5 = tf.keras.layers.Dropout(0.2)
        
        # The last layer needs to be like this:
        self.layer_out = tf.keras.layers.Dense(10, activation='softmax')


    def call(self, inputs):

        x = tf.keras.layers.Flatten()(inputs)
        x = self.layer_1(x)
        
        # The more complex version:
        x = self.layer_2(x)
        x = self.drop_3(x)
        x = self.layer_4(x)
        x = self.drop_5(x)
        
        x = self.layer_out(x)

        return x

# %% [markdown]
# Finally, we again `compile()` the model, this time using [*RMSProp*](https://keras.io/optimizers/#rmsprop) as the optimizer.

# %%
nonlinear_model = NonlinearClassifier()

nonlinear_model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=['accuracy'])

# %% [markdown]
# ### Learning

# %%
# %%time
# This took around half a second per epoch on my laptop for the simpler version, 
# and around 1 second per epoch for the more complex one.
batch_size = 512
epochs = 30
history = nonlinear_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=2)
# Out:
# Epoch 1/30
# 98/98 - 0s - loss: 2.2911 - accuracy: 0.1295 - 487ms/epoch - 5ms/step
# Epoch 2/30
# 98/98 - 0s - loss: 2.2573 - accuracy: 0.1587 - 203ms/epoch - 2ms/step
# Epoch 3/30
# 98/98 - 0s - loss: 2.2147 - accuracy: 0.1849 - 203ms/epoch - 2ms/step
# Epoch 4/30
# 98/98 - 0s - loss: 2.1704 - accuracy: 0.2019 - 209ms/epoch - 2ms/step
# Epoch 5/30
# 98/98 - 0s - loss: 2.1300 - accuracy: 0.2202 - 213ms/epoch - 2ms/step
# Epoch 6/30
# 98/98 - 0s - loss: 2.0967 - accuracy: 0.2299 - 207ms/epoch - 2ms/step
# Epoch 7/30
# 98/98 - 0s - loss: 2.0663 - accuracy: 0.2417 - 206ms/epoch - 2ms/step
# Epoch 8/30
# 98/98 - 0s - loss: 2.0435 - accuracy: 0.2501 - 198ms/epoch - 2ms/step
# Epoch 9/30
# 98/98 - 0s - loss: 2.0211 - accuracy: 0.2547 - 198ms/epoch - 2ms/step
# Epoch 10/30
# 98/98 - 0s - loss: 2.0062 - accuracy: 0.2655 - 202ms/epoch - 2ms/step
# Epoch 11/30
# 98/98 - 0s - loss: 1.9825 - accuracy: 0.2729 - 215ms/epoch - 2ms/step
# Epoch 12/30
# 98/98 - 0s - loss: 1.9741 - accuracy: 0.2778 - 200ms/epoch - 2ms/step
# Epoch 13/30
# 98/98 - 0s - loss: 1.9589 - accuracy: 0.2817 - 200ms/epoch - 2ms/step
# Epoch 14/30
# 98/98 - 0s - loss: 1.9494 - accuracy: 0.2890 - 200ms/epoch - 2ms/step
# Epoch 15/30
# 98/98 - 0s - loss: 1.9372 - accuracy: 0.2962 - 202ms/epoch - 2ms/step
# Epoch 16/30
# 98/98 - 0s - loss: 1.9251 - accuracy: 0.2978 - 209ms/epoch - 2ms/step
# Epoch 17/30
# 98/98 - 0s - loss: 1.9126 - accuracy: 0.3024 - 203ms/epoch - 2ms/step
# Epoch 18/30
# 98/98 - 0s - loss: 1.9071 - accuracy: 0.3066 - 208ms/epoch - 2ms/step
# Epoch 19/30
# 98/98 - 0s - loss: 1.8983 - accuracy: 0.3119 - 204ms/epoch - 2ms/step
# Epoch 20/30
# 98/98 - 0s - loss: 1.8882 - accuracy: 0.3120 - 202ms/epoch - 2ms/step
# Epoch 21/30
# 98/98 - 0s - loss: 1.8813 - accuracy: 0.3172 - 196ms/epoch - 2ms/step
# Epoch 22/30
# 98/98 - 0s - loss: 1.8760 - accuracy: 0.3188 - 203ms/epoch - 2ms/step
# Epoch 23/30
# 98/98 - 0s - loss: 1.8669 - accuracy: 0.3231 - 198ms/epoch - 2ms/step
# Epoch 24/30
# 98/98 - 0s - loss: 1.8590 - accuracy: 0.3287 - 306ms/epoch - 3ms/step
# Epoch 25/30
# 98/98 - 0s - loss: 1.8507 - accuracy: 0.3306 - 248ms/epoch - 3ms/step
# Epoch 26/30
# 98/98 - 0s - loss: 1.8445 - accuracy: 0.3299 - 195ms/epoch - 2ms/step
# Epoch 27/30
# 98/98 - 0s - loss: 1.8394 - accuracy: 0.3339 - 196ms/epoch - 2ms/step
# Epoch 28/30
# 98/98 - 0s - loss: 1.8365 - accuracy: 0.3361 - 197ms/epoch - 2ms/step
# Epoch 29/30
# 98/98 - 0s - loss: 1.8262 - accuracy: 0.3390 - 218ms/epoch - 2ms/step
# Epoch 30/30
# 98/98 - 0s - loss: 1.8210 - accuracy: 0.3417 - 191ms/epoch - 2ms/step
# CPU times: user 11.1 s, sys: 1.45 s, total: 12.5 s
# Wall time: 7.04 s

# %%
plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['loss'])
plt.title('loss')

plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['accuracy'])
plt.title('accuracy');

# %% [markdown]
# ### Inference
#
# Accuracy for test data.  The model should be better than the linear model.

# %%
# %%time
scores = nonlinear_model.evaluate(x_test, y_test, verbose=2)
print("%s: %.2f%%" % (nonlinear_model.metrics_names[1], scores[1]*100))
# Out:
# 313/313 - 0s - loss: 1.7413 - accuracy: 0.3824 - 390ms/epoch - 1ms/step
# accuracy: 38.24%
# CPU times: user 600 ms, sys: 140 ms, total: 740 ms
# Wall time: 498 ms

# %% [markdown]
# We can again take a closer look on the results, using the `show_failures()` function defined earlier.
#
# Here are the first 10 test images the MLP classified to a wrong class:

# %%
predictions = nonlinear_model.predict(x_test)

show_failures(predictions)
# Out:
# 313/313 [==============================] - 0s 767us/step
# Showing max 20 first failures. The predicted class is shown first and the correct class in parenthesis.

# %% [markdown]
# We can use `show_failures()` to inspect failures in more detail. For example, here are failures in which the true class was "6":

# %%
show_failures(predictions, trueclass=6)
# Out:
# Showing max 20 first failures. The predicted class is shown first and the correct class in parenthesis.

# %% [markdown]
# We can also compute the confusion matrix to see which image get mixed the most, and look at classification accuracies separately for each class:

# %%
from sklearn.metrics import confusion_matrix

print('Confusion matrix (rows: true classes; columns: predicted classes):'); print()
cm=confusion_matrix(y_test, numpy.argmax(predictions, axis=1), labels=list(range(10)))
print(cm); print()

print('Classification accuracy for each class:'); print()
for i,j in enumerate(cm.diagonal()/cm.sum(axis=1)): print("%d: %.4f" % (i,j))
# Out:
# Confusion matrix (rows: true classes; columns: predicted classes):
#
# [[456  53  44  15  23  20  31  62 230  66]
#  [ 42 465   6  19  13  25  46  38 139 207]
#  [127  47 180  52 165  65 202  98  40  24]
#  [ 44  93  55 144  62 211 168 124  36  63]
#  [ 65  46 128  60 264  32 238 116  32  19]
#  [ 33  49  51  97  99 317 145 122  59  28]
#  [ 17  55  49  48 125  67 522  73   8  36]
#  [ 50  69  39  49 108  53  89 432  23  88]
#  [114 112   7  28  12  29   5  26 561 106]
#  [ 45 203   7  18   9  10  35  63 127 483]]
#
# Classification accuracy for each class:
#
# 0: 0.4560
# 1: 0.4650
# 2: 0.1800
# 3: 0.1440
# 4: 0.2640
# 5: 0.3170
# 6: 0.5220
# 7: 0.4320
# 8: 0.5610
# 9: 0.4830

# %% [markdown]
# In the next notebook, we'll introduce convolutional layers, which are commonly used for images.

# %% [markdown]
# # In-class exercise: improve the accuracy of this model

# %% [markdown]
# How can you improve model accuracy by increasing epochs, stacking more layers, or changing the optimizer?

# %%
class NonlinearClassifier(tf.keras.models.Model):

    def __init__(self, activation=tf.nn.tanh):
        tf.keras.models.Model.__init__(self)

        self.layer_1 = tf.keras.layers.Dense(50, activation='relu')
        
#         # A bit more complex model: (need to uncomment in call fn as well)
        self.layer_2 = tf.keras.layers.Dense(50, activation='relu')
        self.drop_3 = tf.keras.layers.Dropout(0.2)
        self.layer_4 = tf.keras.layers.Dense(50, activation='relu')
        self.drop_5 = tf.keras.layers.Dropout(0.2)
        self.layer_5 = tf.keras.layers.Dense(50, activation='relu')
        self.drop_6 = tf.keras.layers.Dropout(0.2)
        
        # The last layer needs to be like this:
        self.layer_out = tf.keras.layers.Dense(10, activation='softmax')


    def call(self, inputs):

        x = tf.keras.layers.Flatten()(inputs)
        x = self.layer_1(x)
        
        # The more complex version:
        x = self.layer_2(x)
        x = self.drop_3(x)
        x = self.layer_4(x)
        x = self.drop_5(x)
        x = self.layer_5(x)
        x = self.drop_6(x)
        
        x = self.layer_out(x)

        return x
    
nonlinear_model = NonlinearClassifier()

nonlinear_model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=['accuracy'])    


# This took around half a second per epoch on my laptop for the simpler version, 
# and around 1 second per epoch for the more complex one.
batch_size = 128
epochs = 60
history = nonlinear_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=2)


scores = nonlinear_model.evaluate(x_test, y_test, verbose=2)
print("%s: %.2f%%" % (nonlinear_model.metrics_names[1], scores[1]*100))
# Out:
# Epoch 1/60
# 391/391 - 1s - loss: 2.2372 - accuracy: 0.1592 - 879ms/epoch - 2ms/step
# Epoch 2/60
# 391/391 - 1s - loss: 2.1116 - accuracy: 0.2117 - 615ms/epoch - 2ms/step
# Epoch 3/60
# 391/391 - 1s - loss: 2.0346 - accuracy: 0.2422 - 624ms/epoch - 2ms/step
# Epoch 4/60
# 391/391 - 1s - loss: 1.9877 - accuracy: 0.2612 - 623ms/epoch - 2ms/step
# Epoch 5/60
# 391/391 - 1s - loss: 1.9565 - accuracy: 0.2738 - 623ms/epoch - 2ms/step
# Epoch 6/60
# 391/391 - 1s - loss: 1.9291 - accuracy: 0.2891 - 623ms/epoch - 2ms/step
# Epoch 7/60
# 391/391 - 1s - loss: 1.9080 - accuracy: 0.2978 - 624ms/epoch - 2ms/step
# Epoch 8/60
# 391/391 - 1s - loss: 1.8871 - accuracy: 0.3095 - 618ms/epoch - 2ms/step
# Epoch 9/60
# 391/391 - 1s - loss: 1.8742 - accuracy: 0.3166 - 619ms/epoch - 2ms/step
# Epoch 10/60
# 391/391 - 1s - loss: 1.8602 - accuracy: 0.3235 - 618ms/epoch - 2ms/step
# Epoch 11/60
# 391/391 - 1s - loss: 1.8412 - accuracy: 0.3292 - 610ms/epoch - 2ms/step
# Epoch 12/60
# 391/391 - 1s - loss: 1.8289 - accuracy: 0.3368 - 610ms/epoch - 2ms/step
# Epoch 13/60
# 391/391 - 1s - loss: 1.8149 - accuracy: 0.3437 - 613ms/epoch - 2ms/step
# Epoch 14/60
# 391/391 - 1s - loss: 1.8028 - accuracy: 0.3473 - 614ms/epoch - 2ms/step
# Epoch 15/60
# 391/391 - 1s - loss: 1.7868 - accuracy: 0.3563 - 612ms/epoch - 2ms/step
# Epoch 16/60
# 391/391 - 1s - loss: 1.7780 - accuracy: 0.3579 - 617ms/epoch - 2ms/step
# Epoch 17/60
# 391/391 - 1s - loss: 1.7664 - accuracy: 0.3644 - 621ms/epoch - 2ms/step
# Epoch 18/60
# 391/391 - 1s - loss: 1.7568 - accuracy: 0.3683 - 625ms/epoch - 2ms/step
# Epoch 19/60
# 391/391 - 1s - loss: 1.7439 - accuracy: 0.3731 - 616ms/epoch - 2ms/step
# Epoch 20/60
# 391/391 - 1s - loss: 1.7401 - accuracy: 0.3743 - 617ms/epoch - 2ms/step
# Epoch 21/60
# 391/391 - 1s - loss: 1.7247 - accuracy: 0.3820 - 620ms/epoch - 2ms/step
# Epoch 22/60
# 391/391 - 1s - loss: 1.7170 - accuracy: 0.3826 - 615ms/epoch - 2ms/step
# Epoch 23/60
# 391/391 - 1s - loss: 1.7097 - accuracy: 0.3885 - 609ms/epoch - 2ms/step
# Epoch 24/60
# 391/391 - 1s - loss: 1.6996 - accuracy: 0.3921 - 610ms/epoch - 2ms/step
# Epoch 25/60
# 391/391 - 1s - loss: 1.6931 - accuracy: 0.3941 - 612ms/epoch - 2ms/step
# Epoch 26/60
# 391/391 - 1s - loss: 1.6831 - accuracy: 0.3986 - 610ms/epoch - 2ms/step
# Epoch 27/60
# 391/391 - 1s - loss: 1.6767 - accuracy: 0.3999 - 616ms/epoch - 2ms/step
# Epoch 28/60
# 391/391 - 1s - loss: 1.6695 - accuracy: 0.4008 - 611ms/epoch - 2ms/step
# Epoch 29/60
# 391/391 - 1s - loss: 1.6656 - accuracy: 0.4032 - 618ms/epoch - 2ms/step
# Epoch 30/60
# 391/391 - 1s - loss: 1.6572 - accuracy: 0.4089 - 609ms/epoch - 2ms/step
# Epoch 31/60
# 391/391 - 1s - loss: 1.6527 - accuracy: 0.4082 - 600ms/epoch - 2ms/step
# Epoch 32/60
# 391/391 - 1s - loss: 1.6445 - accuracy: 0.4127 - 607ms/epoch - 2ms/step
# Epoch 33/60
# 391/391 - 1s - loss: 1.6349 - accuracy: 0.4174 - 610ms/epoch - 2ms/step
# Epoch 34/60
# 391/391 - 1s - loss: 1.6294 - accuracy: 0.4187 - 610ms/epoch - 2ms/step
# Epoch 35/60
# 391/391 - 1s - loss: 1.6321 - accuracy: 0.4186 - 612ms/epoch - 2ms/step
# Epoch 36/60
# 391/391 - 1s - loss: 1.6231 - accuracy: 0.4188 - 611ms/epoch - 2ms/step
# Epoch 37/60
# 391/391 - 1s - loss: 1.6184 - accuracy: 0.4228 - 611ms/epoch - 2ms/step
# Epoch 38/60
# 391/391 - 1s - loss: 1.6123 - accuracy: 0.4235 - 613ms/epoch - 2ms/step
# Epoch 39/60
# 391/391 - 1s - loss: 1.6063 - accuracy: 0.4271 - 611ms/epoch - 2ms/step
# Epoch 40/60
# 391/391 - 1s - loss: 1.6043 - accuracy: 0.4305 - 612ms/epoch - 2ms/step
# Epoch 41/60
# 391/391 - 1s - loss: 1.5955 - accuracy: 0.4314 - 609ms/epoch - 2ms/step
# Epoch 42/60
# 391/391 - 1s - loss: 1.5918 - accuracy: 0.4340 - 611ms/epoch - 2ms/step
# Epoch 43/60
# 391/391 - 1s - loss: 1.5916 - accuracy: 0.4317 - 614ms/epoch - 2ms/step
# Epoch 44/60
# 391/391 - 1s - loss: 1.5838 - accuracy: 0.4363 - 609ms/epoch - 2ms/step
# Epoch 45/60
# 391/391 - 1s - loss: 1.5785 - accuracy: 0.4368 - 613ms/epoch - 2ms/step
# Epoch 46/60
# 391/391 - 1s - loss: 1.5781 - accuracy: 0.4389 - 613ms/epoch - 2ms/step
# Epoch 47/60
# 391/391 - 1s - loss: 1.5680 - accuracy: 0.4438 - 774ms/epoch - 2ms/step
# Epoch 48/60
# 391/391 - 1s - loss: 1.5670 - accuracy: 0.4444 - 616ms/epoch - 2ms/step
# Epoch 49/60
# 391/391 - 1s - loss: 1.5636 - accuracy: 0.4431 - 612ms/epoch - 2ms/step
# Epoch 50/60
# 391/391 - 1s - loss: 1.5531 - accuracy: 0.4475 - 611ms/epoch - 2ms/step
# Epoch 51/60
# 391/391 - 1s - loss: 1.5583 - accuracy: 0.4479 - 614ms/epoch - 2ms/step
# Epoch 52/60
# 391/391 - 1s - loss: 1.5507 - accuracy: 0.4460 - 615ms/epoch - 2ms/step
# Epoch 53/60
# 391/391 - 1s - loss: 1.5502 - accuracy: 0.4485 - 612ms/epoch - 2ms/step
# Epoch 54/60
# 391/391 - 1s - loss: 1.5450 - accuracy: 0.4525 - 613ms/epoch - 2ms/step
# Epoch 55/60
# 391/391 - 1s - loss: 1.5413 - accuracy: 0.4541 - 612ms/epoch - 2ms/step
# Epoch 56/60
# 391/391 - 1s - loss: 1.5358 - accuracy: 0.4557 - 614ms/epoch - 2ms/step
# Epoch 57/60
# 391/391 - 1s - loss: 1.5303 - accuracy: 0.4575 - 611ms/epoch - 2ms/step
# Epoch 58/60
# 391/391 - 1s - loss: 1.5362 - accuracy: 0.4574 - 610ms/epoch - 2ms/step
# Epoch 59/60
# 391/391 - 1s - loss: 1.5266 - accuracy: 0.4566 - 610ms/epoch - 2ms/step
# Epoch 60/60
# 391/391 - 1s - loss: 1.5207 - accuracy: 0.4595 - 605ms/epoch - 2ms/step
# 313/313 - 0s - loss: 1.5036 - accuracy: 0.4560 - 397ms/epoch - 1ms/step
# accuracy: 45.60%
